# %%
import pandas as pd
df = pd.read_parquet("data/processed/prices_long.parquet")
print(df.head())
# Out:
#       ticker  trade_date  open  high  low  close    turnover  share_volume  \
# 0  AAF.N0000  2016-01-03   1.6   1.7  1.6    1.7    201761.1        126036
# 1  AAF.N0000  2016-01-04   1.7   1.7  1.7    1.7        20.4            12
# 2  AAF.N0000  2016-01-05   1.6   1.6  1.6    1.6  12860288.0       8037680
# 3  AAF.N0000  2016-01-06   1.6   1.6  1.6    1.6    180510.4        112819
# 4  AAF.N0000  2016-01-07   1.6   1.6  1.6    1.6    107246.4         67029
#
#    trade_volume
# 0            12
# 1             1
# 2            22
# 3             9
# 4            14

# %%
import pandas as pd
df = pd.read_parquet("data/processed/prices_with_returns.parquet")
print(df.loc[df['ticker']=='AAF.N0000', ['trade_date','close','close_pct_return','close_log_return']].head(10))
# Out:
#   trade_date  close  close_pct_return  close_log_return
# 0 2016-01-03    1.7               NaN               NaN
# 1 2016-01-04    1.7          0.000000          0.000000
# 2 2016-01-05    1.6         -0.058824         -0.060625
# 3 2016-01-06    1.6          0.000000          0.000000
# 4 2016-01-07    1.6          0.000000          0.000000
# 5 2016-01-10    1.6          0.000000          0.000000
# 6 2016-01-11    1.6          0.000000          0.000000
# 7 2016-01-12    1.6          0.000000          0.000000
# 8 2016-01-13    1.5         -0.062500         -0.064539
# 9 2016-01-17    1.4         -0.066667         -0.068993
